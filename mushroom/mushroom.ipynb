# %%
import pandas as pd 
file='mushroom.csv'
X_full=pd.read_csv(file)
X_full.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8416.000000  8416.000000  8416.000000  8416.000000  8416.000000
# mean      2.494297     1.733840     4.264734     0.598859     4.828897
# std       0.892014     1.190765     3.403228     0.490159     1.961047
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000     4.000000
# 50%       2.000000     2.000000     3.000000     1.000000     6.000000
# 75%       3.000000     3.000000     8.000000     1.000000     6.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8416.000000   8416.000000  8416.000000  8416.000000  8416.000000
# mean          0.974335      0.189163     0.301331     4.692490     0.577947
# std           0.158144      0.391662     0.458863     3.353737     0.493916
# ...

# %%
X_full.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0        2.0          3.0        8.0      0.0   0.0              1.0
# 1        2.0          3.0        8.0      0.0   0.0              1.0
# 2        2.0          3.0        8.0      0.0   0.0              1.0
# 3        2.0          3.0        8.0      0.0   0.0              1.0
# 4        2.0          3.0        8.0      0.0   0.0              1.0
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0           1.0        1.0        10.0          1.0  ...
# 1           1.0        1.0        10.0          1.0  ...
# 2           1.0        1.0         7.0          1.0  ...
# 3           1.0        1.0         7.0          1.0  ...
# 4           1.0        1.0         1.0          1.0  ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                     7.0                     7.0        0.0         2.0
# ...

# %%
num_true=len(X_full.loc[X_full['mushroom']==1])
num_false=len(X_full.loc[X_full['mushroom']==0])

# %%
print(num_true)
print(num_false)
# Out:
# 3928
# 4488

# %%
y=X_full['mushroom']

# %%
cols_with_missing=[col for col in X_full.columns if X_full[col].isnull().any()]
print(cols_with_missing)
# Out:
# []

# %%
s=(X_full.dtypes=='object')
object_cols=list(s[s].index)
print(object_cols)
# Out:
# []

# %%
corr_matrix=X_full.corr()

# %%
print(corr_matrix)
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.007695  -0.177459  0.198068
# cap-surface               -0.007695     1.000000  -0.018034  0.012510
# cap-color                 -0.177459    -0.018034   1.000000 -0.048034
# bruises                    0.198068     0.012510  -0.048034  1.000000
# odor                       0.248895    -0.107035  -0.324546  0.094744
# gill-attachment            0.029289    -0.157442   0.191475 -0.132833
# gill-spacing              -0.052695    -0.103011  -0.009759  0.330933
# gill-size                  0.256205     0.265984  -0.087007  0.347284
# gill-color                -0.063429    -0.115839  -0.021791 -0.346282
# stalk-shape                0.240525     0.032046  -0.239215 -0.078955
# stalk-root                -0.163409    -0.136590   0.060770 -0.186424
# stalk-surface-above-ring  -0.067737     0.022636   0.002480 -0.385854
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
sn.heatmap(corr_matrix, annot=False)
plt.show()

# %%
del(X_full['stalk-color-below-ring'])
del(X_full['veil-color'])
del(X_full['gill-spacing'])

# %%
import numpy as np
fig = plt.figure() 
ax = fig.add_subplot(111) 
cax = ax.matshow(corr_matrix, vmin=-1, vmax=1) 
fig.colorbar(cax) 
ticks = np.arange(0,20,1) 
ax.set_xticks(ticks) 
ax.set_yticks(ticks)

plt.show()

# %%
print(X_full.columns)
corr_matrix=X_full.corr()
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-size', 'gill-color', 'stalk-shape',
#        'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'veil-type', 'ring-number', 'ring-type',
#        'spore-print-color', 'population', 'habitat', 'mushroom'],
#       dtype='object')

# %%
del(X_full['spore-print-color'])
del(X_full['gill-size'])
del(X_full['bruises'])

# %%
corr_matrix=X_full.corr()
sn.heatmap(corr_matrix, annot=False)
plt.show()

# %%
del(X_full['habitat'])

# %%
del(X_full['veil-type'])

# %%
corr_matrix=X_full.corr()
sn.heatmap(corr_matrix, annot=False)
plt.show()

# %%
X_full.shape
# Out:
# (8416, 15)

# %%
import numpy as np
fig = plt.figure() 
ax = fig.add_subplot(111) 
cax = ax.matshow(corr_matrix, vmin=-1, vmax=1) 
fig.colorbar(cax) 
ticks = np.arange(0,15,1) 
ax.set_xticks(ticks) 
ax.set_yticks(ticks)

plt.show()

# %%
print(X_full.columns)
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'odor', 'gill-attachment',
#        'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring', 'ring-number',
#        'ring-type', 'population', 'mushroom'],
#       dtype='object')

# %%
del(X_full['mushroom'])

# %%
X_full.head()
# Out:
#    cap-shape  cap-surface  cap-color  odor  gill-attachment  gill-color  \
# 0        2.0          3.0        8.0   0.0              1.0        10.0
# 1        2.0          3.0        8.0   0.0              1.0        10.0
# 2        2.0          3.0        8.0   0.0              1.0         7.0
# 3        2.0          3.0        8.0   0.0              1.0         7.0
# 4        2.0          3.0        8.0   0.0              1.0         1.0
#
#    stalk-shape  stalk-root  stalk-surface-above-ring  \
# 0          1.0         1.0                       3.0
# 1          1.0         1.0                       3.0
# 2          1.0         1.0                       3.0
# 3          1.0         1.0                       3.0
# 4          1.0         1.0                       3.0
#
#    stalk-surface-below-ring  stalk-color-above-ring  ring-number  ring-type  \
# 0                       3.0                     7.0          1.0        4.0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_full, y, 
                                                                train_size=0.8, test_size=0.2,
                                                                random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\Amal\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
preds=model.predict(X_valid)
X_valid.head()
# Out:
#       cap-shape  cap-surface  cap-color  odor  gill-attachment  gill-color  \
# 6637        2.0          2.0        0.0   8.0              1.0         2.0
# 2407        2.0          0.0        7.0   6.0              1.0         8.0
# 4858        3.0          0.0        3.0   4.0              1.0         3.0
# 2171        3.0          0.0        0.0   6.0              1.0         1.0
# 2563        2.0          0.0        0.0   6.0              1.0         8.0
#
#       stalk-shape  stalk-root  stalk-surface-above-ring  \
# 6637          1.0         0.0                       3.0
# 2407          1.0         1.0                       3.0
# 4858          0.0         1.0                       2.0
# 2171          1.0         3.0                       0.0
# 2563          1.0         1.0                       3.0
#
#       stalk-surface-below-ring  stalk-color-above-ring  ring-number  \
# 6637                       3.0                     7.0          1.0
# ...

# %%
from sklearn import metrics
print(metrics.accuracy_score(preds,y_valid))
# Out:
# 0.9216152019002375

# %%
X_train.head()
# Out:
#       cap-shape  cap-surface  cap-color  odor  gill-attachment  gill-color  \
# 5371        3.0          2.0        9.0   4.0              1.0         3.0
# 2930        2.0          2.0        0.0   6.0              1.0        10.0
# 7051        3.0          2.0        7.0   3.0              1.0         2.0
# 6382        2.0          3.0        0.0   8.0              1.0         2.0
# 3449        3.0          0.0        0.0   6.0              1.0         1.0
#
#       stalk-shape  stalk-root  stalk-surface-above-ring  \
# 5371          0.0         1.0                       2.0
# 2930          1.0         1.0                       3.0
# 7051          1.0         0.0                       2.0
# 6382          1.0         0.0                       2.0
# 3449          1.0         1.0                       3.0
#
#       stalk-surface-below-ring  stalk-color-above-ring  ring-number  \
# 5371                       2.0                     5.0          1.0
# ...

# %%
from sklearn.naive_bayes import GaussianNB
Mymodel=GaussianNB()
Mymodel.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn import metrics
pred=Mymodel.predict(X_valid)
print(metrics.accuracy_score(pred,y_valid))
# Out:
# 0.7648456057007126
